# %% [markdown]
# ### Testing Customized Storage File

# %%
# Imports
import numpy as np
import pandas as pd
import xarray as xr

# %%
file_h = '/export/scratch/iharp-customized-storage/data/raw/raw_1.nc'
file_d = '/export/scratch/iharp-customized-storage/data/raw/agg_1_day.nc'
file_m = '/export/scratch/iharp-customized-storage/data/raw/agg_1_month.nc'
file_y = '/export/scratch/iharp-customized-storage/data/raw/agg_1_year.nc'

# %%
# Check raw file
h = xr.open_dataset(file_h)
h
# Out:
# <xarray.Dataset> Size: 59MB
# Dimensions:     (valid_time: 8760, latitude: 41, longitude: 41)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 70kB 2003-01-01 ... 2003-12-31T23...
#   * latitude    (latitude) float64 328B -30.0 -30.25 -30.5 ... -39.75 -40.0
#   * longitude   (longitude) float64 328B 30.0 30.25 30.5 ... 39.5 39.75 40.0
#     expver      (valid_time) <U4 140kB ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 59MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T14:21 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
h.rename({'valid_time':'time'})
# Out:
# <xarray.Dataset> Size: 59MB
# Dimensions:    (time: 8760, latitude: 41, longitude: 41)
# Coordinates:
#     number     int64 8B ...
#   * time       (time) datetime64[ns] 70kB 2003-01-01 ... 2003-12-31T23:00:00
#   * latitude   (latitude) float64 328B -30.0 -30.25 -30.5 ... -39.5 -39.75 -40.0
#   * longitude  (longitude) float64 328B 30.0 30.25 30.5 ... 39.5 39.75 40.0
#     expver     (time) <U4 140kB ...
# Data variables:
#     t2m        (time, latitude, longitude) float32 59MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T14:21 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# check temporal aggregations
d = xr.open_dataset(file_d)
d
# Out:
# <xarray.Dataset> Size: 5MB
# Dimensions:    (time: 365, latitude: 41, longitude: 41)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B -30.0 -30.25 -30.5 ... -39.5 -39.75 -40.0
#   * longitude  (longitude) float64 328B 30.0 30.25 30.5 ... 39.5 39.75 40.0
#   * time       (time) datetime64[ns] 3kB 2003-01-01 2003-01-02 ... 2003-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 5MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T14:21 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
m = xr.open_dataset(file_m)
m
# Out:
# <xarray.Dataset> Size: 162kB
# Dimensions:    (time: 12, latitude: 41, longitude: 41)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B -30.0 -30.25 -30.5 ... -39.5 -39.75 -40.0
#   * longitude  (longitude) float64 328B 30.0 30.25 30.5 ... 39.5 39.75 40.0
#   * time       (time) datetime64[ns] 96B 2003-01-31 2003-02-28 ... 2003-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 161kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T14:21 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
y = xr.open_dataset(file_y)
y
# Out:
# <xarray.Dataset> Size: 14kB
# Dimensions:    (time: 1, latitude: 41, longitude: 41)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B -30.0 -30.25 -30.5 ... -39.5 -39.75 -40.0
#   * longitude  (longitude) float64 328B 30.0 30.25 30.5 ... 39.5 39.75 40.0
#   * time       (time) datetime64[ns] 8B 2003-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 13kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T14:21 GRIB to CDM+CF via cfgrib-0.9.1...
