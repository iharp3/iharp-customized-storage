# %% [markdown]
# ### Testing Customized Storage File

# %%
# Imports
import numpy as np
import pandas as pd
import xarray as xr

# %%
file_h = '/export/scratch/iharp-customized-storage/data/raw/raw_2.nc'
file_d = '/export/scratch/iharp-customized-storage/data/raw/agg_2_day.nc'
file_m = '/export/scratch/iharp-customized-storage/data/raw/agg_2_month.nc'
file_y = '/export/scratch/iharp-customized-storage/data/raw/agg_2_year.nc'

file_05 = '/export/scratch/iharp-customized-storage/data/agg/agg_2_day_050.nc'
file_100 = '/export/scratch/iharp-customized-storage/data/agg/agg_2_day_100.nc'

# %%
# Check raw file
h = xr.open_dataset(file_h)
h
# Out:
# <xarray.Dataset> Size: 350MB
# Dimensions:     (valid_time: 26280, latitude: 41, longitude: 81)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 210kB 2021-01-01 ... 2023-12-31T2...
#   * latitude    (latitude) float64 328B 10.0 9.75 9.5 9.25 ... 0.75 0.5 0.25 0.0
#   * longitude   (longitude) float64 648B -20.0 -19.75 -19.5 ... -0.5 -0.25 0.0
#     expver      (valid_time) <U4 420kB ...
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 349MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
h.rename({'valid_time':'time'})
# Out:
# <xarray.Dataset> Size: 350MB
# Dimensions:    (time: 26280, latitude: 41, longitude: 81)
# Coordinates:
#     number     int64 8B ...
#   * time       (time) datetime64[ns] 210kB 2021-01-01 ... 2023-12-31T23:00:00
#   * latitude   (latitude) float64 328B 10.0 9.75 9.5 9.25 ... 0.75 0.5 0.25 0.0
#   * longitude  (longitude) float64 648B -20.0 -19.75 -19.5 ... -0.5 -0.25 0.0
#     expver     (time) <U4 420kB ...
# Data variables:
#     t2m        (time, latitude, longitude) float32 349MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# check temporal aggregations
d = xr.open_dataset(file_d)
d
# Out:
# <xarray.Dataset> Size: 29MB
# Dimensions:    (time: 1095, latitude: 41, longitude: 81)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B 10.0 9.75 9.5 9.25 ... 0.75 0.5 0.25 0.0
#   * longitude  (longitude) float64 648B -20.0 -19.75 -19.5 ... -0.5 -0.25 0.0
#   * time       (time) datetime64[ns] 9kB 2021-01-01 2021-01-02 ... 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 29MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
m = xr.open_dataset(file_m)
m
# Out:
# <xarray.Dataset> Size: 958kB
# Dimensions:    (time: 36, latitude: 41, longitude: 81)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B 10.0 9.75 9.5 9.25 ... 0.75 0.5 0.25 0.0
#   * longitude  (longitude) float64 648B -20.0 -19.75 -19.5 ... -0.5 -0.25 0.0
#   * time       (time) datetime64[ns] 288B 2021-01-31 2021-02-28 ... 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 956kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
y = xr.open_dataset(file_y)
y
# Out:
# <xarray.Dataset> Size: 81kB
# Dimensions:    (time: 3, latitude: 41, longitude: 81)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 328B 10.0 9.75 9.5 9.25 ... 0.75 0.5 0.25 0.0
#   * longitude  (longitude) float64 648B -20.0 -19.75 -19.5 ... -0.5 -0.25 0.0
#   * time       (time) datetime64[ns] 24B 2021-12-31 2022-12-31 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 80kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
d_05 = xr.open_dataset(file_05)
d_05
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:    (time: 1095, latitude: 20, longitude: 40)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 160B 9.875 9.375 8.875 ... 1.375 0.875 0.375
#   * longitude  (longitude) float64 320B -19.88 -19.38 -18.88 ... -0.875 -0.375
#   * time       (time) datetime64[ns] 9kB 2021-01-01 2021-01-02 ... 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 7MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
d_100 = xr.open_dataset(file_100)
d_100
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:    (time: 1095, latitude: 10, longitude: 20)
# Coordinates:
#     number     int64 8B ...
#   * latitude   (latitude) float64 80B 9.625 8.625 7.625 ... 2.625 1.625 0.625
#   * longitude  (longitude) float64 160B -19.62 -18.62 -17.62 ... -1.625 -0.625
#   * time       (time) datetime64[ns] 9kB 2021-01-01 2021-01-02 ... 2023-12-31
# Data variables:
#     t2m        (time, latitude, longitude) float64 2MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-14T15:01 GRIB to CDM+CF via cfgrib-0.9.1...
